# %% [markdown]
# <img src=https://img.gazeta.ru/files3/923/11732923/dicaprio-pic905-895x505-13209.jpg><br><hr style="border: 10px solid green;" />
#
# ## <span style="color:green">Финальный комментарий<span>
#
# Спасибо за проделанную работу🤝
#
# Екатерина, спасибо за доработки, всё принято👌
#
# По Story, если обрезанность - это про размеры, то размеры стори также можно регулировать, просто они внизу страницы:
# ![image.png](attachment:image.png)
#
# Там также можно выбрать Авто или указать любой кастомный размер. Кстати, нет ограничений по высоте дашборда😉
#
# Желаю дальнейших успехов и отличного настроения. В качестве бонуса, рекомендую, отличную книгу про оформление презентаций, графиков - [Александр Богачев, Графики, которые убеждают](https://www.litres.ru/book/aleksandr-bogachev/grafiki-kotorye-ubezhdaut-vseh-51710962/?etext=2202.djJvP5fw5zcFUmVUzOg083M-m18ldNmodGO7Z1JOc7bLnYIKrXldtg0XlPOX_v9Q5Mch8f2FQH7k8NPv74UE1pgqul6_pvxHdoIb3489mCL9EboTkhEDb5vn4iP7FQDTeGJ4aHdwb2dvYmNveHVzZw.08df721efd94a95b67e1454ab87d50432f5c02a3&yclid=2637497238845724830&utm_source=yandex&utm_medium=cpc&utm_campaign=web_books_dsa_drr_feed%20607619718%7C47441382&utm_content=8258473707&utm_term=Раменское_10750) и можно заглянуть в канал и сайт [Ромы Бунина](https://t.me/revealthedata) (кажется, главный человек по визуализации в Росии😉)
#
#
# Интересные ссылки:
# - <a href="https://datayoga.ru/vizcards">Карточки визуализации</a>
# - [Доска Miro Datayoga](https://miro.com/app/board/o9J_kr3cvUM=/)
# - [Марафон визуализации](https://datayoga.ru/datalens01) - он на Datalens, но можно выбрать и другой инструмент
#
#
#
# Поздравляю, проект принят👍

# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Комментарий ревьювера 2
#
# Екатерина, привет! Спасибо за ссылки👌
#
# По твоим вопросам:
#
# 1. Про NULL. Исключить его можно:
#  - или в самих данных при написании SQL
#  - или как у тебя сделано, в фильтре
#
#
# 2. Про проценты. При расчете NPS ты используешь умножение на 100, то есть переводишь доли в проценты, поэтому изменение формата на проценты, приводит к тому, о чем ты пишешь. Если исключишь умножение на 100, то всё будет ОК
# ![image.png](attachment:image.png)
#
#
# 🔴 Доработки:
# 1. Отличное решение не соединять всё в одном месте, но вкладки также можно опубликовать вместе. [Видео](https://youtu.be/iKNbpYqQNCc) поможет разобраться как это сделать
#
# 2. По вкладке с лояльностью. На ней мы видим распределение по группам NPS (чтобы получить лояльность необходимо посчитать разность между доле сторонников и критиков), также в комментариях ты оперируешь долей сторонников и критиков, это может ввести в заблуждение, тк уровень NPS (это и есть лояльность) - расчетная метрика по указанной формуле (как в индикаторе NPS), доля сторонииков - схожа с NPS, но не отражает лояльность, так как возможна ситуация когда доли сторонников и критиков одинаково вырасли за счет нейтралов и следовательно NPS не изменился (хотя доля сторонииков стала выше). Если вышенаписанное тебе понятно, то никаких правок вносить не надо, если это прояснило что-то, то пожалуйста скорректируй комментарии или графики в этой части
#
# 3. В Story только описание сторонников? Так и задумано?<br>
#
# Story - альтернатива презентации, поэтому в ней должно быть представлено всё исследование (то есть ответы на все вопросы исследования)

# %% [markdown]
# ### Комментарий студента
# **Насчет Null поняла, спасибо! По поводу перевода индикатора NPS в проценты - поправила :)**

# %% [markdown]
# **Насчет внесения мной некоей путаницы с соотношением сторонников, нейтралов, критиков и определением лояльности клиентов я поняла, что ты имеешь в виду, Олег, спасибо что обратил на это мое внимание. Я подправила комментарии в этом дашборде.**

# %% [markdown]
# **В Story у меня было только описание сторонников, так как я попыталась тем самым ответить на вопрос Шага 4 Проекта "Как можно описать клиентов, которые относятся к группе cторонников (англ. promoters)?". Исправила, поместила там все исследование (просто еще при выполнении прошлого проекта мне не очень понравилось помещать дашборды в презентации, так как они так получаются какими-то жутко обрезанными и всё равно ничего не видно).**

# %% [markdown]
# Проект с поправками: <https://public.tableau.com/views/NPS_16878640782230/NPS_3?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link>

# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Комментарий ревьювера
#
# Екатерина, привет!
#
# 🤚Меня зовут, Олег Юрьев, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если это неприемлемо, обязательно напиши мне в комментариях - мы перейдем на _ВЫ_ .
#
# 🤝Спасибо, что сдала проект вовремя. Тобой проделана большая работа, молодец!
#
# ✏️В этой тетрадке ты найдешь мои комментарии.
#
# Комментарии будут выделены:
#
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Отличная работа ✅</b><br>
#     Безупречная работа</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>Что можно улучшить ⚠️</b><br>
#     Ничего дорабатывать не надо, данные пункты работают нормально, но есть способы улучшить. Несколько таких комментариев допустимы, но более - придется некоторые доработать. Большое кол-во мелких замечаний и помарок сказываются на общем впечатлении от работы.</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid red 2px; padding: 20px"> <b>Что необходимо доработать ⛔️</b><br>
#     Такие пункты необходимо исправить в первую очередь, чтобы я смог принять проект.</div>
#
# Не удаляй комментарии, так будем следить за динамикой 📈
#
# Давай будем в диалоге - основные цели в диалоге:
# - обмен опытом (да я тоже учусь у студентов👨‍🎓)
# - выполнить проект еще лучше
# - помочь тебе стать аналитиком
#
# Поэтому чтобы мне проще было проверять повторно, а тебе контролировать процесс ревью, оставляй свои комментарии и выделяй их.
#
#
#
#
# Поехали! :)
#
# <hr style="border: 2px solid green;" />

# %%
import os
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

# %%
path_to_db_local = 'telecomm_csi.db'
path_to_db_platform = '/datasets/telecomm_csi.db'
path_to_db = None

if os.path.exists(path_to_db_local):
    path_to_db = path_to_db_local
elif os.path.exists(path_to_db_platform):
    path_to_db = path_to_db_platform
else:
    raise Exception('Файл с базой данных SQLite не найден!')

if path_to_db:
    engine = create_engine(f'sqlite:///{path_to_db}', echo=False)

# %%
query = """
WITH

location_info AS (SELECT country,
                  city,
                  location_id
                  FROM location),
                  
age_info AS (SELECT title AS age_segment,
             age_gr_id
             FROM age_segment),
             
traffic_info AS (SELECT title AS traffic_segment,
                 tr_gr_id
                 FROM traffic_segment),
                 
lifetime_info AS (SELECT title AS lifetime_segment,
                  lt_gr_id
                  FROM lifetime_segment)
                  
                  
SELECT u.user_id,
       u.lt_day,
         CASE
           WHEN lt_day <= 365 THEN 'да'
           WHEN lt_day > 365 THEN 'нет'
         END AS is_new,
       u.age,
       CAST(u.gender_segment AS varchar) AS gender_segment,
       u.os_name,
       u.cpe_type_name,
       u.nps_score,
          CASE 
            WHEN nps_score >= 9 THEN 'сторонник'
            WHEN nps_score = 8 OR nps_score = 7 THEN 'нейтрал'
            WHEN nps_score <= 6 THEN 'критик'
          END AS nps_group,
      location_info.country,
      location_info.city,
      age_info.age_segment,
      traffic_info.traffic_segment,
      lifetime_info.lifetime_segment
FROM user AS u
LEFT OUTER JOIN location_info ON u.location_id=location_info.location_id
LEFT OUTER JOIN age_info ON u.age_gr_id=age_info.age_gr_id
LEFT OUTER JOIN traffic_info ON u.tr_gr_id=traffic_info.tr_gr_id
LEFT OUTER JOIN lifetime_info ON u.lt_gr_id=lifetime_info.lt_gr_id;
"""

# %%
df = pd.read_sql(query, engine)
df.head(10)
# Out:
#   user_id  lt_day is_new   age gender_segment  os_name cpe_type_name  \
# 0  A001A2    2320    нет  45.0            1.0  ANDROID    SMARTPHONE
# 1  A001WF    2344    нет  53.0            0.0  ANDROID    SMARTPHONE
# 2  A003Q7     467    нет  57.0            0.0  ANDROID    SMARTPHONE
# 3  A004TB    4190    нет  44.0            1.0      IOS    SMARTPHONE
# 4  A004XT    1163    нет  24.0            0.0  ANDROID    SMARTPHONE
# 5  A005O0    5501    нет  42.0            1.0  ANDROID    SMARTPHONE
# 6  A0061R    1236    нет  45.0            0.0  ANDROID    SMARTPHONE
# 7  A009KS     313     да  35.0            0.0  ANDROID    SMARTPHONE
# 8  A00AES    3238    нет  36.0            1.0  ANDROID    SMARTPHONE
# 9  A00F70    4479    нет  54.0            1.0  ANDROID    SMARTPHONE
#
#    nps_score  nps_group country            city age_segment traffic_segment  \
# 0         10  сторонник  Россия             Уфа    05 45-54          04 1-5
# ...

# %%
df.to_csv('telecomm_csi_tableau.csv', index=False)

# %% [markdown]
# **Здравствуй, Олег! Я думала, что когда я отправляю подобную ссылку, отправляется вся Book из Tableau...буду знать, что это не так)) Прикрепляю новые ссылки. (Дашборда у меня два, так как мне показалось было бы неправильно запихивать все подготовленные для исследования визуализации в один дашборд, было бы очень мелко и неудобно.)**

# %% [markdown]
# Дашборд 1 <https://public.tableau.com/views/NPS_16878640782230/sheet9?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link>

# %% [markdown]
# Дашборд 2 <https://public.tableau.com/views/NPS_16878640782230/NPS_2?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link>

# %% [markdown]
# Презентация <https://public.tableau.com/views/NPS_16878640782230/-?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link>

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px">
#
# ## Общий комментарий
#
#
# Спасибо за проделанную работу🤝
#
# Екатерина, ниже комментарии по разделам проекта:
#
#
# **Pipeline**
#
# ✅ SQL запрос написан корректно!
#
#
# 💡Улучшения: можно заметить, что наименования сегментов составные - номер группы + диапазон значений, это не очень удобно для восприятия и анализа. Чтобы поправить этот момент, можно выделить только диапазон, в этом поможет функция <a href="https://www.sqlitetutorial.net/sqlite-functions/sqlite-substr/">substr</a>
#
#  ----------------------
#
# **Dash**
#
# В целом дашборд выполнен хорошо, но есть что улучшить👇
#
# Вижу так (хотя в комментарии указано _дашборды и презентация_ ):
# ![image.png](attachment:image.png)
#
# Полагаю опубликованы не все вкладки🤔
#
# 🔴Доработки:
# - классно, что есть всплывающая таблица с NPS, но не лишним будет добавить [динамический индикатор NPS](https://youtu.be/sjP-ipvhhgk)
# - кросс-фильтрация графиков - хорошее решение, тогда нужно или делать для всех графиков или добавлять отдельные фильтры, чтобы детальнее изучать данные. Например, хорошо бы иметь возможность фильтрации по полу\старый(новый)\возраст\город\группа NPS
#
#
# 💡Улучшения:
# - градиент по NPS. В целом я за исключение такого решения по двум причинам:
#  - при неудачном выборе палитры, будут такие артефакты
# ![image-2.png](attachment:image-2.png)
#  - если изменение градиента совпадает с возрастанием\убыванием категорий, то анализировать график удобно и просто. А если не совпадает (города), то мы получаем некоторый "забор" из градиентов.
#
# На мой взгляд, можно изменить подход и использовать следующие варианты:
# - [combination plot](https://youtu.be/L2oolkmhKL8)
# - [linear plot](https://youtu.be/hT9rEtviQCw)
# - испольовать раздельные графики для кол-ва и NPS
#
#  ----------------------
#
# **Slides**
#
# 🔴Доработки
# - жду ссылки на презу или Story в Табло
#
#
#  Исправляй и отправляй на проверку🛠

# %% [markdown]
# **Я добавила на дашборд 1 фильтр по полу, но подскажи пожалуйста, как оттуда убрать категорию "Null"? Также сделала индикатор NPS, но когда пытаюсь отобразить его в процентах, он выдает "2200,1%" вместо 22,1%*.**
